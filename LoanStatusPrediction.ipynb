# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection and processing part

# %%
loan_data = pd.read_csv('/content/train_u6lujuX_CVtuZ9i (1).csv')

# %%
loan_data.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
type(loan_data)
# Out:
# pandas.core.frame.DataFrame

# %%
loan_data.shape
# Out:
# (614, 13)

# %%
loan_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  ...  Loan_Amount_Term  Credit_History
# count       614.000000         614.000000  ...         600.00000      564.000000
# mean       5403.459283        1621.245798  ...         342.00000        0.842199
# std        6109.041673        2926.248369  ...          65.12041        0.364878
# min         150.000000           0.000000  ...          12.00000        0.000000
# 25%        2877.500000           0.000000  ...         360.00000        1.000000
# 50%        3812.500000        1188.500000  ...         360.00000        1.000000
# 75%        5795.000000        2297.250000  ...         360.00000        1.000000
# max       81000.000000       41667.000000  ...         480.00000        1.000000
#
# [8 rows x 5 columns]

# %%
#number of missing values
loan_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#drop missing values 
#if any one column having NaN whole row will be removed
loan_data = loan_data.dropna()
loan_data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#label encoding
#1 for yes 0 for no
#this is dictionary dataset
loan_data.replace({'Loan_Status':{'N':0,'Y':1}},inplace=True)

# %%
loan_data.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 1  LP001003   Male     Yes  ...            1.0         Rural           0
# 2  LP001005   Male     Yes  ...            1.0         Urban           1
# 3  LP001006   Male     Yes  ...            1.0         Urban           1
# 4  LP001008   Male      No  ...            1.0         Urban           1
# 5  LP001011   Male     Yes  ...            1.0         Urban           1
#
# [5 rows x 13 columns]

# %%
#Dependant column values
loan_data['Dependents'].value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
#replacing value of 3+ to 4
loan_data=loan_data.replace(to_replace='3+' , value=4)
loan_data['Dependents'].value_counts()
# Out:
# 0    274
# 2     85
# 1     80
# 4     41
# Name: Dependents, dtype: int64

# %% [markdown]
# Visualising the data

# %%
#education and loan status
sns.countplot(x='Education',hue='Loan_Status',data=loan_data)

# %%
#marital status & loan status
sns.countplot(x='Married',hue='Loan_Status',data=loan_data)

# %%
#employee type and Property area
sns.countplot(x='Self_Employed',hue='Property_Area',data=loan_data)

# %%
#convert categorical  text into numerical values
loan_dataset = loan_data.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},
                                'Self_Employed':{'No':0,'Yes':1},'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},
                                'Education':{'Graduate':1,'Not Graduate':0}})

# %%
loan_dataset.tail()
# Out:
#       Loan_ID  Gender  Married  ... Credit_History  Property_Area  Loan_Status
# 609  LP002978       0        0  ...            1.0              0            1
# 610  LP002979       1        1  ...            1.0              0            1
# 611  LP002983       1        1  ...            1.0              2            1
# 612  LP002984       1        1  ...            1.0              2            1
# 613  LP002990       0        0  ...            0.0              1            0
#
# [5 rows x 13 columns]

# %%
#separating the data and the label
x = loan_dataset.drop(columns=['Loan_ID','Loan_Status'],axis=1)
y = loan_dataset['Loan_Status']

# %%
print(x)
print(y)
# Out:
#      Gender  Married  ... Credit_History  Property_Area
# 1         1        1  ...            1.0              0
# 2         1        1  ...            1.0              2
# 3         1        1  ...            1.0              2
# 4         1        0  ...            1.0              2
# 5         1        1  ...            1.0              2
# ..      ...      ...  ...            ...            ...
# 609       0        0  ...            1.0              0
# 610       1        1  ...            1.0              0
# 611       1        1  ...            1.0              2
# 612       1        1  ...            1.0              2
# 613       0        0  ...            0.0              1
#
# [480 rows x 11 columns]
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 480, dtype: int64

# %% [markdown]
# Splitting data into train and test

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (480, 11) (432, 11) (48, 11)

# %% [markdown]
# **Training the Support Vector Machine Model**

# %%
classifier = svm.SVC(kernel='linear')

# %%
#training SVM
classifier.fit(x_train,y_train)
#this will take some time
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %%
#accuracy score on training data
x_train_prediction = classifier.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy score of the training model is =  ',training_data_accuracy)
# Out:
# Accuracy score of the training model is =   0.7986111111111112

# %%
#accuracy score on test data !!Important!!
x_test_prediction = classifier.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print('Test data accuracy score is = ',test_data_accuracy)
# Out:
# Test data accuracy score is =  0.8333333333333334

# %% [markdown]
# ***x_train is data present in the dataset
#  , x_test is the data we are getting other than already present data, like out of syllabus qtn***

# %%
loan_dataset.tail()
# Out:
#       Loan_ID  Gender  Married  ... Credit_History  Property_Area  Loan_Status
# 609  LP002978       0        0  ...            1.0              0            1
# 610  LP002979       1        1  ...            1.0              0            1
# 611  LP002983       1        1  ...            1.0              2            1
# 612  LP002984       1        1  ...            1.0              2            1
# 613  LP002990       0        0  ...            0.0              1            0
#
# [5 rows x 13 columns]

# %% [markdown]
# Making a predictive system

# %%
input_data = (1,0,2,0,0,3000,250.0,200.0,180.0,0.0,2)

input_data_as_numpy_array = np.asarray(input_data)

#model predicting only one instance
input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)  
prediction = classifier.predict(input_data_reshaped)

print(prediction)
if(prediction[0] == 0):
  print('Not Sanctioned')
else:
  print('Loan Sanctioned')
# Out:
# [0]
# Not Sanctioned
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
